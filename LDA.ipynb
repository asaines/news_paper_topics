# %% [markdown]
# # Topic modelling

# %%
import os
import pandas as pd
from nltk.tokenize import RegexpTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.decomposition import LatentDirichletAllocation
import nltk

# %%
data = pd.read_csv('abcnews-date-text.csv')
data_text = data[['headline_text']]
data_text['index'] = data_text.index
documents = data_text

# %% [markdown]
# ## Preprocess

# %%
# Load Dataset
df = pd.read_csv('abcnews-date-text.csv')
docs= df['headline_text']
df.head()
# Out:
#    publish_date                                      headline_text
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219     act fire witnesses must be aware of defamation
# 2      20030219     a g calls for infrastructure protection summit
# 3      20030219           air nz staff in aust strike for pay rise
# 4      20030219      air nz strike to affect australian travellers

# %%
# Download the stopwords list if you haven't already
nltk.download('stopwords')

# %%
# Out:
# 0          aba decides against community broadcasting lic...
# 1             act fire witnesses must be aware of defamation
# 2             a g calls for infrastructure protection summit
# 3                   air nz staff in aust strike for pay rise
# 4              air nz strike to affect australian travellers
#                                  ...
# 1244179    two aged care residents die as state records 2...
# 1244180    victoria records 5;919 new cases and seven deaths
# 1244181      wa delays adopting new close contact definition
# 1244182    western ringtail possums found badly dehydrate...
# 1244183    what makes you a close covid contact here are ...
# Name: headline_text, Length: 1244184, dtype: object

# %%
# tokenization
first_text_list = nltk.word_tokenize(docs)
#Stop word removal
#stopwords = nltk.corpus.stopwords.words('english')
# Lemmatization

# %% [markdown]
# ## Latent Dirichlet Allocation

# %%
# Initialize regex tokenizer
tokenizer = RegexpTokenizer(r'\w+')

# Vectorize document using TF-IDF
tfidf = TfidfVectorizer(lowercase=True,
                        stop_words='english',
                        ngram_range = (1,1),
                        tokenizer = tokenizer.tokenize)

# Fit and Transform the documents
train_data = tfidf.fit_transform(docs)
# Out:
# c:\Users\asaines\miniconda3\envs\tm\lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
# Define the number of topics or components
num_components=5

# Create LDA object
model=LatentDirichletAllocation(n_components=num_components)

# Fit and Transform SVD model on data
lda_matrix = model.fit_transform(train_data)

# Get Components 
lda_components=model.components_

# %%
# Print the topics with their terms
terms = tfidf.get_feature_names_out()

for index, component in enumerate(lda_components):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:7]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['says', 'election', 'new', 'interview', 'labor', 'minister', 'pm']
# Topic 1:  ['govt', 'water', 'new', 'council', 'market', 'nsw', 'plan']
# Topic 2:  ['win', 'drum', 'tigers', 'final', 'league', 'sydney', 'strike']
# Topic 3:  ['interview', 'world', 'australia', 'cup', 'day', 'new', 'test']
# Topic 4:  ['police', 'man', 'crash', 'charged', 'court', 'murder', 'car']

# %% [markdown]
# ## Topic Visualization

# %%
from sklearn.manifold import TSNE
tsne_lsa_model = TSNE(n_components=2, perplexity=50, learning_rate=100, 
                        n_iter=2000, verbose=1, random_state=0, angle=0.75)
tsne_lsa_vectors = tsne_lsa_model.fit_transform(lda_matrix)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 
 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1102000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1103000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1104000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1105000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1106000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1107000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1108000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1109000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1110000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1111000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1112000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1113000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1114000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1115000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1116000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1117000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1118000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1119000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1120000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1121000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1122000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1123000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1124000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1125000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1126000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1127000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1128000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1129000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1130000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1131000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1132000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1133000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1134000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1135000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1136000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1137000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1138000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1139000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1140000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1141000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1142000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1143000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1144000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1145000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1146000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1147000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1148000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1149000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1150000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1151000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1152000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1153000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1154000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1155000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1156000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1157000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1158000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1159000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1160000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1161000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1162000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1163000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1164000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1165000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1166000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1167000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1168000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1169000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1170000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1171000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1172000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1173000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1174000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1175000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1176000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1177000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1178000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1179000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1180000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1181000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1182000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1183000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1184000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1185000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1186000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1187000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1188000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1189000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1190000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1191000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1192000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1193000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1194000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1195000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1196000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1197000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1198000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1199000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1200000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1201000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1202000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1203000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1204000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1205000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1206000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1207000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1208000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1209000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1210000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1211000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1212000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1213000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1214000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1215000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1216000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1217000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1218000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1219000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1220000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1221000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1222000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1223000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1224000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1225000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1226000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1227000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1228000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1229000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1230000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1231000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1232000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1233000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1234000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1235000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1236000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1237000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1238000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1239000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1240000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1241000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1242000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1243000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1244000 / 1244184
# [t-SNE] Computed conditional probabilities for sample 1244184 / 1244184
# [t-SNE] Mean sigma: 0.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 4
#       1 from sklearn.manifold import TSNE
#       2 tsne_lsa_model = TSNE(n_components=2, perplexity=50, learning_rate=100,
#       3                         n_iter=2000, verbose=1, random_state=0, angle=0.75)
# ----> 4 tsne_lsa_vectors = tsne_lsa_model.fit_transform(lda_matrix)
#
# File c:\Users\asaines\miniconda3\envs\tm\lib\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File c:\Users\asaines\miniconda3\envs\tm\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\asaines\miniconda3\envs\tm\lib\site-packages\sklearn\manifold\_t_sne.py:1111, in TSNE.fit_transform(self, X, y)
#    1090 """Fit X into an embedded space and return that transformed output.
#    1091
#    1092 Parameters
#    (...)
#    1108     Embedding of the training data in low-dimensional space.
#    1109 """
#    1110 self._check_params_vs_input(X)
# -> 1111 embedding = self._fit(X)
#    1112 self.embedding_ = embedding
#    1113 return self.embedding_
#
# File c:\Users\asaines\miniconda3\envs\tm\lib\site-packages\sklearn\manifold\_t_sne.py:1001, in TSNE._fit(self, X, skip_num_points)
#     995 # Degrees of freedom of the Student's t-distribution. The suggestion
#     996 # degrees_of_freedom = n_components - 1 comes from
#     997 # "Learning a Parametric Embedding by Preserving Local Structure"
#     998 # Laurens van der Maaten, 2009.
#     999 degrees_of_freedom = max(self.n_components - 1, 1)
# -> 1001 return self._tsne(
#    1002     P,
#    1003     degrees_of_freedom,
#    1004     n_samples,
#    1005     X_embedded=X_embedded,
#    1006     neighbors=neighbors_nn,
#    1007     skip_num_points=skip_num_points,
#    1008 )
#
# File c:\Users\asaines\miniconda3\envs\tm\lib\site-packages\sklearn\manifold\_t_sne.py:1053, in TSNE._tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#    1050 # Learning schedule (part 1): do 250 iteration with lower momentum but
#    1051 # higher learning rate controlled via the early exaggeration parameter
#    1052 P *= self.early_exaggeration
# -> 1053 params, kl_divergence, it = _gradient_descent(obj_func, params, **opt_args)
#    1054 if self.verbose:
#    1055     print(
#    1056         "[t-SNE] KL divergence after %d iterations with early exaggeration: %f"
#    1057         % (it + 1, kl_divergence)
#    1058     )
#
# File c:\Users\asaines\miniconda3\envs\tm\lib\site-packages\sklearn\manifold\_t_sne.py:402, in _gradient_descent(objective, p0, it, n_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     399 # only compute the error when needed
#     400 kwargs["compute_error"] = check_convergence or i == n_iter - 1
# --> 402 error, grad = objective(p, *args, **kwargs)
#     404 inc = update * grad < 0.0
#     405 dec = np.invert(inc)
#
# File c:\Users\asaines\miniconda3\envs\tm\lib\site-packages\sklearn\manifold\_t_sne.py:283, in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose, compute_error, num_threads)
#     280 indptr = P.indptr.astype(np.int64, copy=False)
#     282 grad = np.zeros(X_embedded.shape, dtype=np.float32)
# --> 283 error = _barnes_hut_tsne.gradient(
#     284     val_P,
#     285     X_embedded,
#     286     neighbors,
#     287     indptr,
#     288     grad,
#     289     angle,
#     290     n_components,
#     291     verbose,
#     292     dof=degrees_of_freedom,
#     293     compute_error=compute_error,
#     294     num_threads=num_threads,
#     295 )
#     296 c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#     297 grad = grad.ravel()
#
# KeyboardInterrupt:

# %%
colormap = np.array([
    "#1f77b4", "#aec7e8", "#ff7f0e", "#ffbb78", "#2ca02c",
    "#98df8a", "#d62728", "#ff9896", "#9467bd", "#c5b0d5",
    "#8c564b", "#c49c94", "#e377c2", "#f7b6d2", "#7f7f7f",
    "#c7c7c7", "#bcbd22", "#dbdb8d", "#17becf", "#9edae5" ])
colormap = colormap[:n_topics]

top_3_words_lsa = get_top_n_words(3, lsa_keys, small_document_term_matrix, small_count_vectorizer)
lsa_mean_topic_vectors = get_mean_topic_vectors(lsa_keys, tsne_lsa_vectors)

plot = figure(title="t-SNE Clustering of {} LSA Topics".format(n_topics), plot_width=700, plot_height=700)
plot.scatter(x=tsne_lsa_vectors[:,0], y=tsne_lsa_vectors[:,1], color=colormap[lsa_keys])

for t in range(n_topics):
    label = Label(x=lsa_mean_topic_vectors[t][0], y=lsa_mean_topic_vectors[t][1], 
                  text=top_3_words_lsa[t], text_color=colormap[t])
    plot.add_layout(label)
    
show(plot)

# %% [markdown]
# ## Optimal number of topics selection
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4597325/
# https://cran.r-project.org/web/packages/ldatuning/vignettes/topics.html
# https://stackoverflow.com/questions/17421887/how-to-determine-the-number-of-topics-for-lda?rq=4
# https://investigate.ai/text-analysis/choosing-the-right-number-of-topics-for-a-scikit-learn-topic-model/
# https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html#sphx-glr-auto-examples-applications-plot-topics-extraction-with-nmf-lda-py

# %% [markdown]
# ## How do these topics evolve through time in the ABC news headlines?
